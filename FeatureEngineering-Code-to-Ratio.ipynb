# %%
# %run development/libraries/placements-proxy

# %%
def array_deduplicates(arr):
  if arr:
    return list(set(arr))
  else:
    return []
array_deduplicates = udf(array_deduplicates, ArrayType(StringType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
directory = 's3a://sa-matching-dev/placements_proxy_jobsdb/exploratory/hk/data'
country = 'hk'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train = spark.read.parquet("s3a://exploratory/"+country+"/data/train_v4")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(train.select('Job_Industry').limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>JsGlobal_JobSeekerWorkExperience_Industry</th></tr></thead><tbody><tr><td>List(49, 17)</td></tr><tr><td>List(65, 65)</td></tr><tr><td>List(66, 39, 66, 41, 66)</td></tr><tr><td>null</td></tr><tr><td>List(41, 2)</td></tr></tbody></table></div>

# %%
display(train.select(array_deduplicates('Job_Industry')).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array_deduplicates(JsGlobal_JobSeekerWorkExperience_Industry)</th></tr></thead><tbody><tr><td>List(17, 49)</td></tr><tr><td>List(65)</td></tr><tr><td>List(39, 66, 41)</td></tr><tr><td>List()</td></tr><tr><td>List(2, 41)</td></tr></tbody></table></div>

# %%
industry_dataset = train.select(
  'JobAd_IndustryId',
  array_deduplicates('Job_Industry').alias('Job_Industry'),
  'label'
).select(
  explode('Candidate_Industry').alias('Candidate_Industry'),
  'JobAd_IndustryId',
  'label'
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Breakdown the ratio function

# %%
def generate_ratio_lookup(dataset, left_col, right_col, label_col='label', ratio_col='ratio', min_sample=20):
    base_positive = dataset.filter(
      col(label_col) == 1
    ).groupBy(
      left_col,
      right_col
    ).agg(count("*").alias('total_lr')).join(
      dataset.filter(col(label_col) == 1).select(col(left_col).alias('l_lookup')).groupBy('l_lookup').agg(count('*').alias('total_l')),
      [col(left_col) == col('l_lookup')]
    ).withColumn('ratio_p', col('total_lr') / col('total_l')).filter(col('total_l') > min_sample)
    
    base_negative = dataset.filter(
    col(label_col) == 0
  ).groupBy(
    left_col,
    right_col
  ).agg(count("*").alias('total_lr')).join(
    dataset.filter(col(label_col) == 0).select(col(left_col).alias('l_lookup')).groupBy('l_lookup').agg(count('*').alias('total_l')),
    [col(left_col) == col('l_lookup')]
  ).withColumn('ratio_n', col('total_lr') / col('total_l')).filter(col('total_l') > min_sample)
    
    base_lookup = base_positive.select(
      left_col,
      right_col,
      'ratio_p'
    ).join(
      base_negative.select(
        left_col,
        right_col,
        'ratio_n'
      ), 
      on=[left_col,right_col],
      how="full_outer"
    ).fillna(
      {'ratio_p' : 0, 'ratio_n' : 0}
    ).withColumn(
      ratio_col, 
      col('ratio_p') - col('ratio_n')
    ).select(left_col,right_col,ratio_col)
    
    return base_lookup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#only positive
display(generate_ratio_lookup(industry_dataset , 'Candidate_Industry' , 'JobAd_IndustryId' , label_col='label', ratio_col='ratio', min_sample=20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
</td><td>56</td><td>7</td><td>63</td><td>602</td><td>0.011627906976744186</td></tr><tr><td>33</td><td>58</td><td>2</td><td>33</td><td>906</td><td>0.002207505518763797</td></tr><tr><td>36</td><td>51</td><td>6</td><td>36</td><td>2056</td><td>0.0029182879377431907</td></tr><tr><td>35</td><td>9</td><td>1</td><td>35</td><td>130</td><td>0.007692307692307693</td></tr><tr><td>62</td><td>22</td><td>3</td><td>62</td><td>832</td><td>0.003605769230769231</td></tr><tr><td>59</td><td>57</td><td>3</td><td>59</td><td>187</td><td>0.016042780748663103</td></tr><tr><td>24</td><td>66</td><td>214</td><td>24</td><td>2369</td><td>0.09033347403967919</td></tr><tr><td>17</td><td>22</td><td>3</td><td>17</td><td>276</td><td>0.010869565217391304</td></tr><tr><td>31</td><td>37</td><td>38</td><td>31</td><td>2301</td><td>0.016514558887440245</td></tr><tr><td>22</td><td>2</td><td>5</td><td>22</td><td>74</td><td>0.06756756756756757</td></tr><tr><td>10</td><td>16< ...

# %%
def generate_ratio_lookup_negative(dataset, left_col, right_col, label_col='label', ratio_col='ratio', min_sample=20):

    base_negative = dataset.filter(
      col(label_col) == 0
    ).groupBy(
      left_col,
      right_col
    ).agg(count("*").alias('total_lr')).join(
      dataset.filter(col(label_col) == 0).select(col(left_col).alias('l_lookup')).groupBy('l_lookup').agg(count('*').alias('total_l')),
      [col(left_col) == col('l_lookup')]
    ).withColumn('ratio_n', col('total_lr') / col('total_l')).filter(col('total_l') > min_sample)

   
    return base_negative
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#only negative
display(generate_ratio_lookup_negative(industry_dataset , 'JsGlobal_JobSeekerWorkExperience_Industry' , 'JobAd_IndustryId' , label_col='label', ratio_col='ratio', min_sample=20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>JsGlobal_JobSeekerWorkExperience_Industry</th><th>JobAd_IndustryId</th><th>total_lr</th><th>l_lookup</th><th>total_l</th><th>ratio_n</th></tr></thead><tbody><tr><td>2</td><td>40</td><td>45</td><td>2</td><td>18076</td><td>0.0024894888249612744</td></tr><tr><td>41</td><td>31</td><td>149</td><td>41</td><td>4093</td><td>0.036403615929635966</td></tr><tr><td>1</td><td>41</td><td>108</td><td>1</td><td>11937</td><td>0.009047499371701432</td></tr><tr><td>20</td><td>64</td><td>40</td><td>20</td><td>3906</td><td>0.010240655401945725</td></tr><tr><td>56</td><td>33</td><td>59</td><td>56</td><td>4656</td><td>0.012671821305841924</td></tr><tr><td>49</td><td>17</td><td>19</td><td>49</td><td>6470</td><td>0.002936630602782071</td></tr><tr><td>58</td><td>62</td><td>20</td><td>58</td><td>1139</td><td>0.01755926251097454</td></tr><tr><td>3</td><td>49</td><td>2</td><td>3</td><td>126</td><td>0.015873015873015872</td></tr><tr><td>2</td><td>22</td><td>1</td><td>2</td><td>18076</td><td>5.532197388802833E-5</td></tr><tr><td>55</td><td>41</td><td>2</td><td>55</td><td>502</td><td>0.00398406374501992</td></tr><tr><td>37</td><td>24</td