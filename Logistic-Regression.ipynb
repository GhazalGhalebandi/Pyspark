>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: string (nullable = true)
# -- x1_common: string (nullable = true)
# -- x2_common: string (nullable = true)
# -- label: string (nullable = true)
# -- pii: string (nullable = true)
# -- AEF4WWEIRL: string (nullable = true)
# -- W1GZOJ08EO: string (nullable = true)
# -- BZEZO9N92C: string (nullable = true)
# -- R07UHWAHJS: string (nullable = true)
# -- 2WRC17IY73: string (nullable = true)
# -- A9HHX76KTM: string (nullable = true)
# -- Z32DK0RBYO: string (nullable = true)
# -- BD6MYSRUED: string (nullable = true)
# -- ZGJTWQKEHJ: string (nullable = true)
#
# </div>

# %%
df_str_int = df.select(
col('label').cast(IntegerType()),
col('_c0').cast(IntegerType()),
col('x1_common').cast(IntegerType()),
col('x2_common').cast(IntegerType()),
# col('pii').cast(IntegerType()),
col('AEF4WWEIRL').cast(IntegerType()),
col('W1GZOJ08EO').cast(IntegerType()),
col('BZEZO9N92C').cast(IntegerType()),
col('R07UHWAHJS').cast(IntegerType()),
col('2WRC17IY73').cast(IntegerType()),
col('A9HHX76KTM').cast(IntegerType()),
col('Z32DK0RBYO').cast(IntegerType()),
col('BD6MYSRUED').cast(IntegerType()),
col('ZGJTWQKEHJ').cast(IntegerType()),
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_str_int.select([count(when(col(c).isNull(), c)).alias(c) for c in df_str_int.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>_c0</th><th>x1_common</th><th>x2_common</th><th>AEF4WWEIRL</th><th>W1GZOJ08EO</th><th>BZEZO9N92C</th><th>R07UHWAHJS</th><th>2WRC17IY73</th><th>A9HHX76KTM</th><th>Z32DK0RBYO</th><th>BD6MYSRUED</th><th>ZGJTWQKEHJ</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td></tr></tbody></table></div>

# %%
df_no_null = df_str_int.fillna(0)
display(df_no_null.select([count(when(col(c).isNull(), c)).alias(c) for c in df_no_null.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>_c0</th><th>x1_common</th><th>x2_common</th><th>AEF4WWEIRL</th><th>W1GZOJ08EO</th><th>BZEZO9N92C</th><th>R07UHWAHJS</th><th>2WRC17IY73</th><th>A9HHX76KTM</th><th>Z32DK0RBYO</th><th>BD6MYSRUED</th><th>ZGJTWQKEHJ</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
features = df_no_null.drop('label').columns
va = VectorAssembler(inputCols=features, outputCol="features")
dataset_assembled = va.transform(df_no_null)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
(train , test) = dataset_assembled.randomSplit([0.6, 0.4])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
logistic_regression = LogisticRegression(labelCol="label", featuresCol="features", maxIter=10)
model = logistic_regression.fit(train)
predictions = model.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
confusion_matrix = predictions.groupBy('label').pivot('prediction').count()
display(confusion_matrix)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>0.0</th><th>1.0</th></tr></thead><tbody><tr><td>1</td><td>109</td><td>1071</td></tr><tr><td>0</td><td>3978</td><td>80</td></tr></tbody></table></div>

# %%
TP = 1071
TN = 3978
FP = 80
FN = 109

cm = confusion_matrix.collect()
print("Test Accuracy: {0}".format((cm[0][2]+train_results[1][1])/train.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">116</span><span class="ansired">]: </span>[Row(label=1, 0.0=109, 1.0=1071), Row(label=0, 0.0=3978, 1.0=80)]
# </div>

# %%
evaluator = BinaryClassificationEvaluator()
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">120</span><span class="ansired">]: </span>0.9941686645337523
# </div>

# %%
evaluator = BinaryClassificationEvaluator(labelCol="label", metricName="areaUnderROC")
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">122</span><span class="ansired">]: </span>0.9941686645337523
# </div>
