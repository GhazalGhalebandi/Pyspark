# %% [markdown]
# ### Analyze the dataset and come up with some insights that will help us to predict both requested and successful appointments
# ### How would you recommend that we can leverage this data to improve our products or services?

# %%
from pyspark.sql.types import *
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.ml.feature import IndexToString, StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/DS_Sample_Data-c561c.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "True"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source</th><th>campaign</th><th>region</th><th>locality</th><th>preferred_doctor_gender</th><th>dental_anxiety</th><th>last_visited_a_dentist</th><th>how_soon_they_want_to_book</th><th>reason_for_visit</th><th>patient_insured</th><th>number_of_match_results</th><th>out_network_results_shown</th><th>in_network_results_shown</th><th>avg_distance_overall</th><th>appointment_requested</th><th>appointment_status</th><th>appointment_scheduled</th><th>appointment_billed</th><th>chosen_provider_insurance_status</th><th>chosen_provider_distance</th></tr></thead><tbody><tr><td>facebook</td><td>san_diego_dentist_patient_acquisition</td><td>San Jose</td><td>San Jose</td><td>No Pref</td><td>A little nervous</td><td>< 1 year</td><td>ASAP</td><td>Specific Treatment</td><td>f</td><td>9</td><td>0</td><td>0</td><td>10547.21951</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>san_diego_dentist_patient_acquisition</td><td>San Diego</td><td>Chula Vista</td><td>F</td><td>Not at all nervous</td><td>2+ years</td><td>2 weeks</td><td>Checkup & Cleaning</td><td>f</td><td>2</td><td>0</td><td>0</td><td>20784.61772</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>try.opencare.com</td><td>Unknown</td><td>Austin</td><td>Austin</td><td>No Pref</td><td>Moderately nervous</td><td>2+ years</td><td>ASAP</td><td>Checkup & Cleaning</td><td>t</td><td>9</td><td>8</td><td>1</td><td>8014.945931</td><td>t</td><td>CANCELLED</td><td>f</td><td>f</td><td>in-network</td><td>2855.594821</td></tr><tr><td>facebook</td><td>denver_dentist_patient_acquisition</td><td>Denver</td><td>Golden</td><td>No Pref</td><td>Not at all nervous</td><td>< 1 year</td><td>ASAP</td><td>Specific Treatment</td><td>t</td><td>8</td><td>2</td><td>6</td><td>16651.15875</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>chicago_dentist_patient_acquisition</td><td>Chicago</td><td>Chicago</td><td>F</td><td>Not at all nervous</td><td>< 1 year</td><td>1 week</td><td>Checkup & Cleaning</td><td>f</td><td>9</td><td>0</td><td>0</td><td>5216.934559</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Direct</td><td>Unknown</td><td>San Francisco</td><td>San Francisco</td><td>No Pref</td><td>Moderately nervous</td><td>2+ years</td><td>ASAP</td><td>Urgent Issue</td><td>t</td><td>9</td><td>8</td><td>1</td><td>2150.607797</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>chicago_dentist_patient_acquisition</td><td>Chicago</td><td>Hanover Park</td><td>F</td><td>Not at all nervous</td><td>1 - 2 years</td><td>2 weeks</td><td>Checkup & Cleaning</td><td>t</td><td>3</td><td>2</td><td>1</td><td>21242.31032</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Direct</td><td>Unknown</td><td>San Francisco</td><td>San Francisco</td><td>No Pref</td><td>Moderately nervous</td><td>2+ years</td><td>ASAP</td><td>Urgent Issue</td><td>t</td><td>9</td><td>5</td><td>4</td><td>2150.607797</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>www.opencare.com</td><td>Unknown</td><td>Seattle</td><td>Renton</td><td>No Pref</td><td>Not at all nervous</td><td>1 - 2 years</td><td>No preference</td><td>Checkup & Cleaning</td><td>t</td><td>9</td><td>3</td><td>6</td><td>9143.70618</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>adwords</td><td>search_chicago_local</td><td>Chicago</td><td>Ottawa</td><td>No Pref</td><td>A little nervous</td><td>< 1 year</td><td>ASAP</td><td>Urgent Issue</td><td>t</td><td>0</td><td>0</td><td>0</td><td>null</td><td>f</td><td>null</td><td>f</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>austin_dentist_patient_acquisition</td><td ...

# %%
display(df.groupBy("appointment_requested").count().withColumn('%' , percentage('count')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>9148</td><td>76.66136</td></tr><tr><td>t</td><td>2785</td><td>23.33864</td></tr></tbody></table></div>

# %%
display(df.groupBy("appointment_billed").count().withColumn('%' , percentage('count')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>null</td><td>9153</td><td>76.70326</td></tr><tr><td>f</td><td>1574</td><td>13.190312</td></tr><tr><td>t</td><td>1206</td><td>10.106427</td></tr></tbody></table></div>

# %%
percentage = udf(lambda x: x*100/11933, FloatType())
nested_groupby = df.groupby('appointment_requested', 'appointment_status' , 'appointment_billed').count()
nested_groupby_percentage = nested_groupby.withColumn('%' , percentage('count'))
display(nested_groupby_percentage)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>SCHEDULED</td><td>f</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>CANCELLED</td><td>null</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>REQUESTED</td><td>t</td><td>34</td><td>0.28492415</td></tr><tr><td>f</td><td>null</td><td>null</td><td>9148</td><td>76.66136</td></tr><tr><td>t</td><td>SCHEDULED</td><td>t</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>REQUESTED</td><td>null</td><td>4</td><td>0.03352049</td></tr><tr><td>t</td><td>COMPLETED</td><td>t</td><td>1163</td><td>9.746082</td></tr><tr><td>t</td><td>COMPLETED</td><td>f</td><td>295</td><td>2.472136</td></tr><tr><td>t</td><td>CANCELLED</td><td>f</td><td>1270</td><td>10.6427555</td></tr><tr><td>t</td><td>CREATED</td><td>t</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>REQUESTED</td><td>f</td><td>8</td><td>0.06704098</td></tr></tbody></table></div>

# %% [markdown]
# - patients who request == 77%
# - patients who dont == 23%

# %%
target_feature_app_requested = df.groupby('appointment_requested').count().withColumn('%' , percentage('count'))
display(target_feature_app_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>9148</td><td>76.66136</td></tr><tr><td>t</td><td>2785</td><td>23.33864</td></tr></tbody></table></div>

# %% [markdown]
# # Analysing the impact of features

# %% [markdown]
# # Source

# %%
source = df.groupby('appointment_requested', 'source').count().withColumn('%' , percentage('count'))
display(source)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>source</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>try.opencare.com</td><td>307</td><td>2.5726976</td></tr><tr><td>f</td><td>www.opencare.com</td><td>514</td><td>4.307383</td></tr><tr><td>f</td><td>www.webcrawler.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search.myway.com:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>search.tb.ask.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>patient_leads_jun_2018</td><td>62</td><td>0.5195676</td></tr><tr><td>f</td><td>www.avaorthodontics.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.tedforddental.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>start.att.net</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>gmail</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.drloewinger.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>m.facebook.com</td><td>10</td><td>0.083801225</td></tr><tr><td>f</td><td>patient_leads_may_2018</td><td>6</td><td>0.050280735</td></tr><tr><td>f</td><td>growsumo</td><td>96</td><td>0.80449176</td></tr><tr><td>f</td><td>SEO - Profile</td><td>5</td><td>0.041900612</td></tr><tr><td>f</td><td>l.instagram.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>www.premierdentalboerne.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search.pch.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>egglestonoms.clickforward.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>drip_gift_card_4</td><td>60</td><td>0.5028073</td></tr><tr><td>f</td><td>www.totalhealthdentalpc.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>gmail</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>null</td><td>12</td><td>0.10056147</td></tr><tr><td>t</td><td>cancellation</td><td>5</td><td>0.041900612</td></tr><tr><td>f</td><td>app.opencare.com</td><td>4</td><td>0.03352049</td></tr><tr><td>t</td><td>mail.google.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>duckduckgo.com</td><td>6</td><td>0.050280735</td></tr><tr><td>t</td><td>may_long_weekend</td><td>8</td><td>0.06704098</td></tr><tr><td>f</td><td>drip_no_card_4</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>drip_gift_card_1</td><td>6</td><td>0.050280735</td></tr><tr><td>t</td><td>N/A</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>facebook</td><td>5648</td><td>47.330933</td></tr><tr><td>t</td><td>adwords</td><td>197</td><td>1.6508842</td></tr><tr><td>t</td><td>Direct</td><td>53</td><td>0.44414648</td></tr><tr><td>t</td><td>dnserrorassist.att.net</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>Direct</td><td>189</td><td>1.5838431</td></tr><tr><td>f</td><td>l.facebook.com:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.ecosia.org</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>dentistfrisco-tx.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>growsumo</td><td>51</td><td>0.42738625</td></tr><tr><td>t</td><td>lm.facebook.com</td><td>7</td><td>0.058660857</td></tr><tr><td>f</td><td>patient.opencare.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>l.facebook.com:443</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.searchencrypt.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>l.facebook.com</td><td>27</td><td>0.2262633</td></tr><tr><td>f</td><td>city_all_static_interests_all_20to40_sf_sf</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>drip_no_card_4</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>www.8to8dentalcare.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>Branded - SEO</td><td>238</td><td>1.9944692</td></tr><tr><td>f</td><td>www.health247.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>opencare.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td> ...

# %%
source_requested = source.filter(col('appointment_requested')== 't').sort('%')
display(source_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>source</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>dnserrorassist.att.net</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>mail.google.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>city_all_static_interests_all_20to40_sf_sf</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>patient.opencare.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>instagram.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>direct_mail</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>opencare.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>N/A</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>search.tb.ask.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>drip_no_card_4</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>noshow</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>gmail</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>null</td><td>3</td><td>0.025140367</td></tr><tr><td>t</td><td>cancellation</td><td>5</td><td>0.041900612</td></tr><tr><td>t</td><td>lm.facebook.com</td><td>7</td><td>0.058660857</td></tr><tr><td>t</td><td>may_long_weekend</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>l.facebook.com</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>patient_leads_may_2018</td><td>10</td><td>0.083801225</td></tr><tr><td>t</td><td>m.facebook.com</td><td>10</td><td>0.083801225</td></tr><tr><td>t</td><td>www.facebook.com</td><td>15</td><td>0.12570183</td></tr><tr><td>t</td><td>SEO - C/S Page</td><td>24</td><td>0.20112294</td></tr><tr><td>t</td><td>jan_2018_high_offer</td><td>28</td><td>0.23464343</td></tr><tr><td>t</td><td>Branded - Adwords</td><td>31</td><td>0.2597838</td></tr><tr><td>t</td><td>patient_leads_jun_2018</td><td>33</td><td>0.27654403</td></tr><tr><td>t</td><td>drip_gift_card_4</td><td>43</td><td>0.36034527</td></tr><tr><td>t</td><td>growsumo</td><td>51</td><td>0.42738625</td></tr><tr><td>t</td><td>Direct</td><td>53</td><td>0.44414648</td></tr><tr><td>t</td><td>Branded - SEO</td><td>64</td><td>0.53632784</td></tr><tr><td>t</td><td>try.opencare.com</td><td>100</td><td>0.8380122</td></tr><tr><td>t</td><td>www.opencare.com</td><td>119</td><td>0.9972346</td></tr><tr><td>t</td><td>adwords</td><td>197</td><td>1.6508842</td></tr><tr><td>t</td><td>Patients</td><td>259</td><td>2.1704516</td></tr><tr><td>t</td><td>facebook</td><td>1702</td><td>14.262968</td></tr></tbody></table></div>

# %%
source_not_requested = source.filter(col('appointment_requested')== 'f').sort('%')
display(source_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>source</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>l.facebook.com:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>egglestonoms.clickforward.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search.myway.com:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.health247.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.totalhealthdentalpc.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.ltsmiles.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>mckinneysmiles.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.drloewinger.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>try.opencare.com:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.drmerey.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.webcrawler.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>r.search.aol.com:443</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.avaorthodontics.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>results.searchlock.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.mycedarparkdentist.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search.tb.ask.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.ecosia.org</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.tedforddental.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>dentistfrisco-tx.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>alluredentalsf.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.premierdentalboerne.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>l.facebook.com:443</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.colbertdentalcenter.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search.pch.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.stephengordondds.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>start.att.net</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.thedowntowndentistcs.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>city_all_static_interests_all_20to40_sf_sf</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.ecklandfamilydentistry.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.manosdecristo.org:80</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>www.8to8dentalcare.com</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>gmail</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>feb_2018_email_blast</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>drip_no_card_4</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>noshow</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>patient.opencare.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>www-amarillodentalworks-com.filesusr.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>www.searchencrypt.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>www.collaborativefund.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>N/A</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>l.instagram.com</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>direct_mail</td><td>3</td><td>0.025140367</td></tr><tr><td>f</td><td>r.search.aol.com</td><td>4</td><td>0.03352049</td></tr><tr><td>f</td><td>app.opencare.com</td><td>4</td><td>0.03352049</td></tr><tr><td>f</td><td>april_2018_email_blast</td><td>4</td><td>0.03352049</td></tr><tr><td>f</td><td>SEO - Profile</td><td>5</td><td>0.041900612</td></tr><tr><td>f</td><td>patient_leads_may_2018</td><td>6</td><td>0.050280735</td></tr><tr><td>f</td><td>drip_gift_card_1</td><td>6</td><td>0.050280735</td></tr><tr><td>f</td><td>duckduckgo.com</ ...

# %% [markdown]
# source = facebook
# - requested = 14 %
# - not requested = 47 %

# %%
# Facebook as source in total 
print(facebook_source.groupBy().sum().collect())
print("source from facebook :", (7641/df.count())*100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(sum(count)=7641)]
# source from facebook : 64.03251487471718
# </div>

# %%
# Opencare as source in total 
print(opencare_source.groupBy().sum().collect())
print("source from opencare :", (1059/df.count())*100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(sum(count)=1059)]
# source from opencare : 8.8745495684237
# </div>

# %% [markdown]
# # Campaign

# %%
campaign = df.groupby('appointment_requested', 'campaign').count().withColumn('%' , percentage('count'))
display(campaign)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>campaign</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>search_chicago_local</td><td>273</td><td>2.2877734</td></tr><tr><td>f</td><td>denver_patients</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>chicago_dentist_patient_remarketing</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>patients</td><td>3</td><td>0.025140367</td></tr><tr><td>f</td><td>patient_leads_jun_2018</td><td>143</td><td>1.1983575</td></tr><tr><td>f</td><td>search_seattle_local</td><td>109</td><td>0.9134333</td></tr><tr><td>t</td><td>Unknown</td><td>639</td><td>5.354898</td></tr><tr><td>f</td><td>us_dentist_patient_acquisition</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>chicago_dentist_patient_acquisition</td><td>993</td><td>8.321462</td></tr><tr><td>f</td><td>search_chicago_metro</td><td>125</td><td>1.0475153</td></tr><tr><td>f</td><td>chicago_dentist_patient_acquisition_opencare</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>april_2018_referral_drip_leads</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>search_austin_metro</td><td>36</td><td>0.3016844</td></tr><tr><td>f</td><td>patient_leads_may_2018</td><td>33</td><td>0.27654403</td></tr><tr><td>f</td><td>Free Credits</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>main_chicago</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>main_seattle</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>san_francisco_dentist_patient_acquisition</td><td>228</td><td>1.9106679</td></tr><tr><td>f</td><td>site_link</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>new</td><td>17</td><td>0.14246207</td></tr><tr><td>f</td><td>null</td><td>3</td><td>0.025140367</td></tr><tr><td>t</td><td>sanfrancisco_dentist_patient_acquisition</td><td>5</td><td>0.041900612</td></tr><tr><td>t</td><td>patient_leads_feb_2018</td><td>7</td><td>0.058660857</td></tr><tr><td>t</td><td>us_dentist_patient_acquisition</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>san_jose_dentist_patient_acquisition</td><td>485</td><td>4.064359</td></tr><tr><td>f</td><td>san_francisco_dentist_patient_acquisition</td><td>839</td><td>7.030923</td></tr><tr><td>t</td><td>search_seattle_local</td><td>25</td><td>0.20950305</td></tr><tr><td>f</td><td>patient_leads</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>san_diego_dentist_patient_acquisition</td><td>378</td><td>3.1676862</td></tr><tr><td>f</td><td>us_patients</td><td>15</td><td>0.12570183</td></tr><tr><td>f</td><td>patient_leads_feb_2018</td><td>4</td><td>0.03352049</td></tr><tr><td>t</td><td>san_diego_dentist_patient_acquisition</td><td>112</td><td>0.9385737</td></tr><tr><td>f</td><td>toronto_dentist_patient_acquisition</td><td>16</td><td>0.13408196</td></tr><tr><td>t</td><td>search_chicago_local</td><td>61</td><td>0.51118743</td></tr><tr><td>t</td><td>us_dentist_patient_remarketing</td><td>18</td><td>0.1508422</td></tr><tr><td>t</td><td>search_austin_local</td><td>34</td><td>0.28492415</td></tr><tr><td>t</td><td>branded_keywords</td><td>36</td><td>0.3016844</td></tr><tr><td>t</td><td>new</td><td>15</td><td>0.12570183</td></tr><tr><td>f</td><td>search_sanfrancisco_metro</td><td>155</td><td>1.298919</td></tr><tr><td>t</td><td>search_chicago_metro</td><td>11</td><td>0.09218135</td></tr><tr><td>f</td><td>sanfrancisco_dentist_patient_acquisition</td><td>42</td><td>0.35196513</td></tr><tr><td>f</td><td>branded_keywords</td><td>95</td><td>0.79611164</td></tr><tr><td>t</td><td>chicago_dentist_patient_acquisition</td><td>324</td><td>2.7151597</td></tr><tr><td>t</td><td>dentist_patient_acquisition</td><td>67</td><td>0.5614682</td></tr><tr><td>f</td><td>dentist_patient_acquisition</td><td>212</td><td>1.7765859</td></tr><tr><td>t</td><td>denver_dentist_patient_acquisition</td><td>197</td><td>1.6508842</td></tr><tr><td>f</td><td>us_dentist_patient_remarketing</td ...

# %%
campaign_requested = campaign.filter(col('appointment_requested')== 't').sort('%')
display(campaign_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>campaign</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>us_dentist_patient_acquisition</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>site_link</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>null</td><td>3</td><td>0.025140367</td></tr><tr><td>t</td><td>toronto_dentist_patient_acquisition</td><td>5</td><td>0.041900612</td></tr><tr><td>t</td><td>search_austin_metro</td><td>5</td><td>0.041900612</td></tr><tr><td>t</td><td>sanfrancisco_dentist_patient_acquisition</td><td>5</td><td>0.041900612</td></tr><tr><td>t</td><td>patient_leads_feb_2018</td><td>7</td><td>0.058660857</td></tr><tr><td>t</td><td>us_dentist_patient_ad_testing</td><td>9</td><td>0.0754211</td></tr><tr><td>t</td><td>patient_leads_mar_2018</td><td>9</td><td>0.0754211</td></tr><tr><td>t</td><td>search_chicago_metro</td><td>11</td><td>0.09218135</td></tr><tr><td>t</td><td>opencare_facebook_page</td><td>11</td><td>0.09218135</td></tr><tr><td>t</td><td>new</td><td>15</td><td>0.12570183</td></tr><tr><td>t</td><td>search_sanfrancisco_metro</td><td>17</td><td>0.14246207</td></tr><tr><td>t</td><td>us_dentist_patient_remarketing</td><td>18</td><td>0.1508422</td></tr><tr><td>t</td><td>search_sanfrancisco_local</td><td>19</td><td>0.15922232</td></tr><tr><td>t</td><td>search_seattle_local</td><td>25</td><td>0.20950305</td></tr><tr><td>t</td><td>patient_leads_may_2018</td><td>31</td><td>0.2597838</td></tr><tr><td>t</td><td>search_seattle_metro</td><td>31</td><td>0.2597838</td></tr><tr><td>t</td><td>search_austin_local</td><td>34</td><td>0.28492415</td></tr><tr><td>t</td><td>branded_keywords</td><td>36</td><td>0.3016844</td></tr><tr><td>t</td><td>jan_2018_high_offer</td><td>37</td><td>0.31006452</td></tr><tr><td>t</td><td>search_chicago_local</td><td>61</td><td>0.51118743</td></tr><tr><td>t</td><td>dentist_patient_acquisition</td><td>67</td><td>0.5614682</td></tr><tr><td>t</td><td>patient_leads_jun_2018</td><td>85</td><td>0.7123104</td></tr><tr><td>t</td><td>san_diego_dentist_patient_acquisition</td><td>112</td><td>0.9385737</td></tr><tr><td>t</td><td>san_jose_dentist_patient_acquisition</td><td>124</td><td>1.0391352</td></tr><tr><td>t</td><td>denver_dentist_patient_acquisition</td><td>197</td><td>1.6508842</td></tr><tr><td>t</td><td>san_francisco_dentist_patient_acquisition</td><td>228</td><td>1.9106679</td></tr><tr><td>t</td><td>austin_dentist_patient_acquisition</td><td>291</td><td>2.4386156</td></tr><tr><td>t</td><td>chicago_dentist_patient_acquisition</td><td>324</td><td>2.7151597</td></tr><tr><td>t</td><td>seattle_dentist_patient_acquisition</td><td>327</td><td>2.7403</td></tr><tr><td>t</td><td>Unknown</td><td>639</td><td>5.354898</td></tr></tbody></table></div>

# %%
campaign_not_requested = campaign.filter(col('appointment_requested')== 'f').sort('%')
display(campaign_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>campaign</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>denver_patients</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>Free Credits</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>feb_2018_email_blast</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>main_seattle</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>chicago_dentist_patient_remarketing</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>chicato_dentist_patient_acquisition</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>chicago_dentist_patient_acquisition_opencare</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>seattle_dentist_patient_acquisition_opencare</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>seattle_dentist_patient_remarketing</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>uber</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>patient_leads</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>april_2018_referral_drip_leads</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>site_link</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>us_dentist_patient_acquisition</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>main_chicago</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>seattle_dentist_patient_acquisition_targeted</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>null</td><td>3</td><td>0.025140367</td></tr><tr><td>f</td><td>patients</td><td>3</td><td>0.025140367</td></tr><tr><td>f</td><td>same</td><td>3</td><td>0.025140367</td></tr><tr><td>f</td><td>patient_leads_feb_2018</td><td>4</td><td>0.03352049</td></tr><tr><td>f</td><td>april_2018_email_blast</td><td>6</td><td>0.050280735</td></tr><tr><td>f</td><td>us_patients</td><td>15</td><td>0.12570183</td></tr><tr><td>f</td><td>toronto_dentist_patient_acquisition</td><td>16</td><td>0.13408196</td></tr><tr><td>f</td><td>new</td><td>17</td><td>0.14246207</td></tr><tr><td>f</td><td>patient_leads_mar_2018</td><td>21</td><td>0.17598256</td></tr><tr><td>f</td><td>us_dentist_patient_ad_testing</td><td>29</td><td>0.24302354</td></tr><tr><td>f</td><td>patient_leads_may_2018</td><td>33</td><td>0.27654403</td></tr><tr><td>f</td><td>opencare_facebook_page</td><td>35</td><td>0.2933043</td></tr><tr><td>f</td><td>search_austin_metro</td><td>36</td><td>0.3016844</td></tr><tr><td>f</td><td>sanfrancisco_dentist_patient_acquisition</td><td>42</td><td>0.35196513</td></tr><tr><td>f</td><td>us_dentist_patient_remarketing</td><td>50</td><td>0.4190061</td></tr><tr><td>f</td><td>jan_2018_high_offer</td><td>70</td><td>0.5866086</td></tr><tr><td>f</td><td>branded_keywords</td><td>95</td><td>0.79611164</td></tr><tr><td>f</td><td>search_seattle_local</td><td>109</td><td>0.9134333</td></tr><tr><td>f</td><td>search_sanfrancisco_local</td><td>125</td><td>1.0475153</td></tr><tr><td>f</td><td>search_chicago_metro</td><td>125</td><td>1.0475153</td></tr><tr><td>f</td><td>patient_leads_jun_2018</td><td>143</td><td>1.1983575</td></tr><tr><td>f</td><td>search_austin_local</td><td>143</td><td>1.1983575</td></tr><tr><td>f</td><td>search_sanfrancisco_metro</td><td>155</td><td>1.298919</td></tr><tr><td>f</td><td>search_seattle_metro</td><td>206</td><td>1.7263052</td></tr><tr><td>f</td><td>dentist_patient_acquisition</td><td>212</td><td>1.7765859</td></tr><tr><td>f</td><td>search_chicago_local</td><td>273</td><td>2.2877734</td></tr><tr><td>f</td><td>san_diego_dentist_patient_acquisition</td><td>378</td><td>3.1676862</td></tr><tr><td>f</td><td>san_jose_dentist_patient_acquisition</td><td>485</td><td>4.064359</td></tr><tr><td>f</td><td>denver_dentist_patient_acquisition</td><td>591</td><td>4.9526525</td></tr><tr><td>f</td><td>san_francisco_dentist_patient_acquisition</td><td>839</td><td>7.030923</td></tr><tr><td>f</td><td>chicago_dentist_patient_acquisition< ...

# %% [markdown]
# top 3 : austin , seatle , chicago
# - requested 2% +
# - not requested 9% and 8%

# %% [markdown]
# # Region

# %%
region = df.groupby('appointment_requested', 'region').count().withColumn('%' , percentage('count'))
display(region)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>region</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>Chicago</td><td>1916</td><td>16.056314</td></tr><tr><td>t</td><td>Chicago</td><td>614</td><td>5.1453953</td></tr><tr><td>f</td><td>Denver</td><td>878</td><td>7.3577476</td></tr><tr><td>t</td><td>Seattle</td><td>597</td><td>5.002933</td></tr><tr><td>t</td><td>Denver</td><td>322</td><td>2.6983993</td></tr><tr><td>t</td><td>San Francisco</td><td>460</td><td>3.8548563</td></tr><tr><td>f</td><td>Seattle</td><td>1761</td><td>14.757396</td></tr><tr><td>t</td><td>Austin</td><td>463</td><td>3.8799965</td></tr><tr><td>t</td><td>San Diego</td><td>145</td><td>1.2151177</td></tr><tr><td>f</td><td>Washington DC</td><td>14</td><td>0.117321715</td></tr><tr><td>f</td><td>Austin</td><td>1860</td><td>15.587028</td></tr><tr><td>t</td><td>San Jose</td><td>184</td><td>1.5419425</td></tr><tr><td>f</td><td>San Diego</td><td>474</td><td>3.972178</td></tr><tr><td>f</td><td>San Francisco</td><td>1594</td><td>13.357915</td></tr><tr><td>f</td><td>San Jose</td><td>651</td><td>5.4554596</td></tr></tbody></table></div>

# %%
region_requested = region.filter(col('appointment_requested')== 't').sort('%')
display(region_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>region</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>San Diego</td><td>145</td><td>1.2151177</td></tr><tr><td>t</td><td>San Jose</td><td>184</td><td>1.5419425</td></tr><tr><td>t</td><td>Denver</td><td>322</td><td>2.6983993</td></tr><tr><td>t</td><td>San Francisco</td><td>460</td><td>3.8548563</td></tr><tr><td>t</td><td>Austin</td><td>463</td><td>3.8799965</td></tr><tr><td>t</td><td>Seattle</td><td>597</td><td>5.002933</td></tr><tr><td>t</td><td>Chicago</td><td>614</td><td>5.1453953</td></tr></tbody></table></div>

# %%
region_not_requested = region.filter(col('appointment_requested')== 'f').sort('%')
display(region_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>region</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>Washington DC</td><td>14</td><td>0.117321715</td></tr><tr><td>f</td><td>San Diego</td><td>474</td><td>3.972178</td></tr><tr><td>f</td><td>San Jose</td><td>651</td><td>5.4554596</td></tr><tr><td>f</td><td>Denver</td><td>878</td><td>7.3577476</td></tr><tr><td>f</td><td>San Francisco</td><td>1594</td><td>13.357915</td></tr><tr><td>f</td><td>Seattle</td><td>1761</td><td>14.757396</td></tr><tr><td>f</td><td>Austin</td><td>1860</td><td>15.587028</td></tr><tr><td>f</td><td>Chicago</td><td>1916</td><td>16.056314</td></tr></tbody></table></div>

# %% [markdown]
# top 3 = chicago, austin, seatle

# %% [markdown]
# # preferred_doctor_gender

# %%
preferred_doctor_gender = df.groupby('appointment_requested', 'preferred_doctor_gender').count().withColumn('%' , percentage('count'))
display(preferred_doctor_gender)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>preferred_doctor_gender</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>M</td><td>182</td><td>1.5251822</td></tr><tr><td>t</td><td>F</td><td>382</td><td>3.2012067</td></tr><tr><td>f</td><td>F</td><td>1518</td><td>12.721025</td></tr><tr><td>t</td><td>No Pref</td><td>2221</td><td>18.612251</td></tr><tr><td>f</td><td>No Pref</td><td>6854</td><td>57.43736</td></tr><tr><td>f</td><td>M</td><td>776</td><td>6.502975</td></tr></tbody></table></div>

# %%
preferred_doctor_gender_requested = preferred_doctor_gender.filter(col('appointment_requested')== 't').sort('%')
display(preferred_doctor_gender_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>preferred_doctor_gender</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>M</td><td>182</td><td>1.5251822</td></tr><tr><td>t</td><td>F</td><td>382</td><td>3.2012067</td></tr><tr><td>t</td><td>No Pref</td><td>2221</td><td>18.612251</td></tr></tbody></table></div>

# %%
preferred_doctor_gender_not_requested = preferred_doctor_gender.filter(col('appointment_requested')== 'f').sort('%')
display(preferred_doctor_gender_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>preferred_doctor_gender</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>M</td><td>776</td><td>6.502975</td></tr><tr><td>f</td><td>F</td><td>1518</td><td>12.721025</td></tr><tr><td>f</td><td>No Pref</td><td>6854</td><td>57.43736</td></tr></tbody></table></div>

# %% [markdown]
# # dental_anxiety

# %%
dental_anxiety = df.groupby('appointment_requested', 'dental_anxiety').count().withColumn('%' , percentage('count'))
display(dental_anxiety.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>dental_anxiety</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>null</td><td>7</td><td>0.058660857</td></tr><tr><td>t</td><td>Extremely nervous</td><td>167</td><td>1.3994805</td></tr><tr><td>t</td><td>Very nervous</td><td>205</td><td>1.7179251</td></tr><tr><td>t</td><td>Moderately nervous</td><td>401</td><td>3.360429</td></tr><tr><td>f</td><td>Extremely nervous</td><td>481</td><td>4.030839</td></tr><tr><td>f</td><td>Very nervous</td><td>722</td><td>6.0504484</td></tr><tr><td>t</td><td>A little nervous</td><td>793</td><td>6.6454372</td></tr><tr><td>t</td><td>Not at all nervous</td><td>1217</td><td>10.198609</td></tr><tr><td>f</td><td>Moderately nervous</td><td>1253</td><td>10.500294</td></tr><tr><td>f</td><td>A little nervous</td><td>2430</td><td>20.363697</td></tr><tr><td>f</td><td>Not at all nervous</td><td>4255</td><td>35.65742</td></tr></tbody></table></div>

# %%
dental_anxiety_requested = dental_anxiety.filter(col('appointment_requested')== 't').sort('%')
display(dental_anxiety_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>dental_anxiety</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>Extremely nervous</td><td>167</td><td>1.3994805</td></tr><tr><td>t</td><td>Very nervous</td><td>205</td><td>1.7179251</td></tr><tr><td>t</td><td>Moderately nervous</td><td>401</td><td>3.360429</td></tr><tr><td>t</td><td>A little nervous</td><td>793</td><td>6.6454372</td></tr><tr><td>t</td><td>Not at all nervous</td><td>1217</td><td>10.198609</td></tr></tbody></table></div>

# %%
dental_anxiety_not_requested = dental_anxiety.filter(col('appointment_requested')== 'f').sort('%')
display(dental_anxiety_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>dental_anxiety</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>null</td><td>7</td><td>0.058660857</td></tr><tr><td>f</td><td>Extremely nervous</td><td>481</td><td>4.030839</td></tr><tr><td>f</td><td>Very nervous</td><td>722</td><td>6.0504484</td></tr><tr><td>f</td><td>Moderately nervous</td><td>1253</td><td>10.500294</td></tr><tr><td>f</td><td>A little nervous</td><td>2430</td><td>20.363697</td></tr><tr><td>f</td><td>Not at all nervous</td><td>4255</td><td>35.65742</td></tr></tbody></table></div>

# %% [markdown]
# # last_visited_a_dentist

# %%
last_visited_a_dentist = df.groupby('appointment_requested', 'last_visited_a_dentist').count().withColumn('%' , percentage('count'))
display(last_visited_a_dentist.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>last_visited_a_dentist</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>null</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>Never</td><td>43</td><td>0.36034527</td></tr><tr><td>f</td><td>Never</td><td>256</td><td>2.1453114</td></tr><tr><td>t</td><td>2+ years</td><td>752</td><td>6.301852</td></tr><tr><td>t</td><td>1 - 2 years</td><td>926</td><td>7.759993</td></tr><tr><td>t</td><td>< 1 year</td><td>1062</td><td>8.89969</td></tr><tr><td>f</td><td>2+ years</td><td>2028</td><td>16.994888</td></tr><tr><td>f</td><td>1 - 2 years</td><td>2499</td><td>20.941925</td></tr><tr><td>f</td><td>< 1 year</td><td>4357</td><td>36.51219</td></tr></tbody></table></div>

# %%
last_visited_a_dentist_requested = last_visited_a_dentist.filter(col('appointment_requested')== 't').sort('%')
display(last_visited_a_dentist_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>last_visited_a_dentist</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>Never</td><td>43</td><td>0.36034527</td></tr><tr><td>t</td><td>2+ years</td><td>752</td><td>6.301852</td></tr><tr><td>t</td><td>1 - 2 years</td><td>926</td><td>7.759993</td></tr><tr><td>t</td><td>< 1 year</td><td>1062</td><td>8.89969</td></tr></tbody></table></div>

# %%
last_visited_a_dentist_not_requested = last_visited_a_dentist.filter(col('appointment_requested')== 'f').sort('%')
display(last_visited_a_dentist_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>last_visited_a_dentist</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>null</td><td>8</td><td>0.06704098</td></tr><tr><td>f</td><td>Never</td><td>256</td><td>2.1453114</td></tr><tr><td>f</td><td>2+ years</td><td>2028</td><td>16.994888</td></tr><tr><td>f</td><td>1 - 2 years</td><td>2499</td><td>20.941925</td></tr><tr><td>f</td><td>< 1 year</td><td>4357</td><td>36.51219</td></tr></tbody></table></div>

# %% [markdown]
# # how_soon_they_want_to_book

# %%
how_soon_they_want_to_book = df.groupby('appointment_requested', 'how_soon_they_want_to_book').count().withColumn('%' , percentage('count'))
display(how_soon_they_want_to_book.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>how_soon_they_want_to_book</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>f</td><td>null</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>No preference</td><td>310</td><td>2.597838</td></tr><tr><td>t</td><td>More than 2 weeks</td><td>372</td><td>3.1174054</td></tr><tr><td>t</td><td>1 week</td><td>384</td><td>3.217967</td></tr><tr><td>t</td><td>2 weeks</td><td>638</td><td>5.346518</td></tr><tr><td>t</td><td>ASAP</td><td>1079</td><td>9.042152</td></tr><tr><td>f</td><td>1 week</td><td>1228</td><td>10.290791</td></tr><tr><td>f</td><td>No preference</td><td>1436</td><td>12.033855</td></tr><tr><td>f</td><td>2 weeks</td><td>1859</td><td>15.578648</td></tr><tr><td>f</td><td>More than 2 weeks</td><td>1863</td><td>15.612168</td></tr><tr><td>f</td><td>ASAP</td><td>2754</td><td>23.078857</td></tr></tbody></table></div>

# %%
how_soon_they_want_to_book_requested = how_soon_they_want_to_book.filter(col('appointment_requested')== 't').sort('%')
display(how_soon_they_want_to_book_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>how_soon_they_want_to_book</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>2</td><td>0.016760245</td></tr><tr><td>t</td><td>No preference</td><td>310</td><td>2.597838</td></tr><tr><td>t</td><td>More than 2 weeks</td><td>372</td><td>3.1174054</td></tr><tr><td>t</td><td>1 week</td><td>384</td><td>3.217967</td></tr><tr><td>t</td><td>2 weeks</td><td>638</td><td>5.346518</td></tr><tr><td>t</td><td>ASAP</td><td>1079</td><td>9.042152</td></tr></tbody></table></div>

# %%
how_soon_they_want_to_book_not_requested = how_soon_they_want_to_book.filter(col('appointment_requested')== 'f').sort('%')
display(how_soon_they_want_to_book_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>how_soon_they_want_to_book</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>null</td><td>8</td><td>0.06704098</td></tr><tr><td>f</td><td>1 week</td><td>1228</td><td>10.290791</td></tr><tr><td>f</td><td>No preference</td><td>1436</td><td>12.033855</td></tr><tr><td>f</td><td>2 weeks</td><td>1859</td><td>15.578648</td></tr><tr><td>f</td><td>More than 2 weeks</td><td>1863</td><td>15.612168</td></tr><tr><td>f</td><td>ASAP</td><td>2754</td><td>23.078857</td></tr></tbody></table></div>

# %% [markdown]
# # reason_for_visit

# %%
reason_for_visit = df.groupby('appointment_requested', 'reason_for_visit').count().withColumn('%' , percentage('count'))
display(reason_for_visit.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>reason_for_visit</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>null</td><td>7</td><td>0.058660857</td></tr><tr><td>t</td><td>Urgent Issue</td><td>252</td><td>2.111791</td></tr><tr><td>t</td><td>Specific Treatment</td><td>262</td><td>2.1955922</td></tr><tr><td>f</td><td>Urgent Issue</td><td>962</td><td>8.061678</td></tr><tr><td>f</td><td>Specific Treatment</td><td>1194</td><td>10.005866</td></tr><tr><td>t</td><td>Checkup & Cleaning</td><td>2270</td><td>19.022879</td></tr><tr><td>f</td><td>Checkup & Cleaning</td><td>6985</td><td>58.535156</td></tr></tbody></table></div>

# %%
reason_for_visit_requested = reason_for_visit.filter(col('appointment_requested')== 't').sort('%')
display(reason_for_visit_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>reason_for_visit</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>null</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>Urgent Issue</td><td>252</td><td>2.111791</td></tr><tr><td>t</td><td>Specific Treatment</td><td>262</td><td>2.1955922</td></tr><tr><td>t</td><td>Checkup & Cleaning</td><td>2270</td><td>19.022879</td></tr></tbody></table></div>

# %%
reason_for_visit_not_requested = reason_for_visit.filter(col('appointment_requested')== 'f').sort('%')
display(reason_for_visit_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>reason_for_visit</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>null</td><td>7</td><td>0.058660857</td></tr><tr><td>f</td><td>Urgent Issue</td><td>962</td><td>8.061678</td></tr><tr><td>f</td><td>Specific Treatment</td><td>1194</td><td>10.005866</td></tr><tr><td>f</td><td>Checkup & Cleaning</td><td>6985</td><td>58.535156</td></tr></tbody></table></div>

# %% [markdown]
# # patient_insured

# %%
patient_insured = patient_insured = df.groupby('appointment_requested', 'patient_insured').count().withColumn('%' , percentage('count'))
display(patient_insured.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>patient_insured</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>f</td><td>530</td><td>4.441465</td></tr><tr><td>t</td><td>t</td><td>2255</td><td>18.897177</td></tr><tr><td>f</td><td>f</td><td>2502</td><td>20.967066</td></tr><tr><td>f</td><td>t</td><td>6646</td><td>55.694294</td></tr></tbody></table></div>

# %%
patient_insured_requested = patient_insured.filter(col('appointment_requested')== 't').sort('%')
display(patient_insured_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>patient_insured</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>f</td><td>530</td><td>4.441465</td></tr><tr><td>t</td><td>t</td><td>2255</td><td>18.897177</td></tr></tbody></table></div>

# %%
530*100/2780
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">208</span><span class="ansired">]: </span>19.06474820143885
# </div>

# %%
patient_insured_not_requested = patient_insured.filter(col('appointment_requested')== 'f').sort('%')
display(patient_insured_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>patient_insured</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>f</td><td>2502</td><td>20.967066</td></tr><tr><td>f</td><td>t</td><td>6646</td><td>55.694294</td></tr></tbody></table></div>

# %% [markdown]
# # out_network_results_shown

# %%
out_network_results_shown = df.groupby('appointment_requested', 'out_network_results_shown').count().withColumn('%' , percentage('count'))
display(out_network_results_shown.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>out_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>9</td><td>75</td><td>0.62850916</td></tr><tr><td>t</td><td>8</td><td>116</td><td>0.9720942</td></tr><tr><td>t</td><td>7</td><td>118</td><td>0.9888544</td></tr><tr><td>t</td><td>6</td><td>156</td><td>1.3072991</td></tr><tr><td>t</td><td>5</td><td>184</td><td>1.5419425</td></tr><tr><td>t</td><td>4</td><td>217</td><td>1.8184866</td></tr><tr><td>t</td><td>3</td><td>262</td><td>2.1955922</td></tr><tr><td>t</td><td>2</td><td>284</td><td>2.3799548</td></tr><tr><td>t</td><td>1</td><td>307</td><td>2.5726976</td></tr><tr><td>f</td><td>9</td><td>317</td><td>2.6564987</td></tr><tr><td>f</td><td>8</td><td>345</td><td>2.8911421</td></tr><tr><td>f</td><td>7</td><td>397</td><td>3.3269086</td></tr><tr><td>f</td><td>6</td><td>443</td><td>3.7123942</td></tr><tr><td>f</td><td>5</td><td>514</td><td>4.307383</td></tr><tr><td>f</td><td>4</td><td>599</td><td>5.0196934</td></tr><tr><td>f</td><td>3</td><td>712</td><td>5.966647</td></tr><tr><td>f</td><td>2</td><td>835</td><td>6.997402</td></tr><tr><td>f</td><td>1</td><td>918</td><td>7.692952</td></tr><tr><td>t</td><td>0</td><td>1066</td><td>8.93321</td></tr><tr><td>f</td><td>0</td><td>4068</td><td>34.090336</td></tr></tbody></table></div>

# %%
out_network_results_shown_requested = out_network_results_shown.filter(col('appointment_requested')== 't').sort('%')
display(out_network_results_shown_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>out_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>9</td><td>75</td><td>0.62850916</td></tr><tr><td>t</td><td>8</td><td>116</td><td>0.9720942</td></tr><tr><td>t</td><td>7</td><td>118</td><td>0.9888544</td></tr><tr><td>t</td><td>6</td><td>156</td><td>1.3072991</td></tr><tr><td>t</td><td>5</td><td>184</td><td>1.5419425</td></tr><tr><td>t</td><td>4</td><td>217</td><td>1.8184866</td></tr><tr><td>t</td><td>3</td><td>262</td><td>2.1955922</td></tr><tr><td>t</td><td>2</td><td>284</td><td>2.3799548</td></tr><tr><td>t</td><td>1</td><td>307</td><td>2.5726976</td></tr><tr><td>t</td><td>0</td><td>1066</td><td>8.93321</td></tr></tbody></table></div>

# %%
out_network_results_shown_not_requested = out_network_results_shown.filter(col('appointment_requested')== 'f').sort('%')
display(out_network_results_shown_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>out_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>9</td><td>317</td><td>2.6564987</td></tr><tr><td>f</td><td>8</td><td>345</td><td>2.8911421</td></tr><tr><td>f</td><td>7</td><td>397</td><td>3.3269086</td></tr><tr><td>f</td><td>6</td><td>443</td><td>3.7123942</td></tr><tr><td>f</td><td>5</td><td>514</td><td>4.307383</td></tr><tr><td>f</td><td>4</td><td>599</td><td>5.0196934</td></tr><tr><td>f</td><td>3</td><td>712</td><td>5.966647</td></tr><tr><td>f</td><td>2</td><td>835</td><td>6.997402</td></tr><tr><td>f</td><td>1</td><td>918</td><td>7.692952</td></tr><tr><td>f</td><td>0</td><td>4068</td><td>34.090336</td></tr></tbody></table></div>

# %% [markdown]
# # in_network_results_shown

# %%
in_network_results_shown = df.groupby('appointment_requested', 'in_network_results_shown').count().withColumn('%' , percentage('count'))
display(in_network_results_shown.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>in_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>8</td><td>108</td><td>0.9050532</td></tr><tr><td>t</td><td>2</td><td>189</td><td>1.5838431</td></tr><tr><td>t</td><td>5</td><td>196</td><td>1.642504</td></tr><tr><td>t</td><td>3</td><td>218</td><td>1.8268666</td></tr><tr><td>t</td><td>6</td><td>219</td><td>1.8352468</td></tr><tr><td>t</td><td>7</td><td>220</td><td>1.843627</td></tr><tr><td>t</td><td>4</td><td>224</td><td>1.8771474</td></tr><tr><td>t</td><td>1</td><td>257</td><td>2.1536915</td></tr><tr><td>f</td><td>8</td><td>278</td><td>2.329674</td></tr><tr><td>f</td><td>5</td><td>445</td><td>3.7291543</td></tr><tr><td>t</td><td>9</td><td>455</td><td>3.8129556</td></tr><tr><td>f</td><td>6</td><td>533</td><td>4.466605</td></tr><tr><td>f</td><td>7</td><td>539</td><td>4.5168858</td></tr><tr><td>f</td><td>4</td><td>582</td><td>4.877231</td></tr><tr><td>f</td><td>3</td><td>635</td><td>5.3213778</td></tr><tr><td>f</td><td>2</td><td>658</td><td>5.5141206</td></tr><tr><td>t</td><td>0</td><td>699</td><td>5.8577056</td></tr><tr><td>f</td><td>1</td><td>832</td><td>6.972262</td></tr><tr><td>f</td><td>9</td><td>896</td><td>7.5085897</td></tr><tr><td>f</td><td>0</td><td>3750</td><td>31.425459</td></tr></tbody></table></div>

# %%
in_network_results_shown_requested = in_network_results_shown.filter(col('appointment_requested')== 't').sort('%')
display(in_network_results_shown_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>in_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>8</td><td>108</td><td>0.9050532</td></tr><tr><td>t</td><td>2</td><td>189</td><td>1.5838431</td></tr><tr><td>t</td><td>5</td><td>196</td><td>1.642504</td></tr><tr><td>t</td><td>3</td><td>218</td><td>1.8268666</td></tr><tr><td>t</td><td>6</td><td>219</td><td>1.8352468</td></tr><tr><td>t</td><td>7</td><td>220</td><td>1.843627</td></tr><tr><td>t</td><td>4</td><td>224</td><td>1.8771474</td></tr><tr><td>t</td><td>1</td><td>257</td><td>2.1536915</td></tr><tr><td>t</td><td>9</td><td>455</td><td>3.8129556</td></tr><tr><td>t</td><td>0</td><td>699</td><td>5.8577056</td></tr></tbody></table></div>

# %%
in_network_results_shown_not_requested = in_network_results_shown.filter(col('appointment_requested')== 'f').sort('%')
display(in_network_results_shown_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>in_network_results_shown</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>8</td><td>278</td><td>2.329674</td></tr><tr><td>f</td><td>5</td><td>445</td><td>3.7291543</td></tr><tr><td>f</td><td>6</td><td>533</td><td>4.466605</td></tr><tr><td>f</td><td>7</td><td>539</td><td>4.5168858</td></tr><tr><td>f</td><td>4</td><td>582</td><td>4.877231</td></tr><tr><td>f</td><td>3</td><td>635</td><td>5.3213778</td></tr><tr><td>f</td><td>2</td><td>658</td><td>5.5141206</td></tr><tr><td>f</td><td>1</td><td>832</td><td>6.972262</td></tr><tr><td>f</td><td>9</td><td>896</td><td>7.5085897</td></tr><tr><td>f</td><td>0</td><td>3750</td><td>31.425459</td></tr></tbody></table></div>

# %% [markdown]
# # appointment_status

# %%
appointment_status = df.groupby('appointment_requested', 'appointment_status').count().withColumn('%' , percentage('count'))
display(appointment_status.sort("%"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>CREATED</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>SCHEDULED</td><td>9</td><td>0.0754211</td></tr><tr><td>t</td><td>REQUESTED</td><td>46</td><td>0.38548562</td></tr><tr><td>t</td><td>CANCELLED</td><td>1271</td><td>10.651135</td></tr><tr><td>t</td><td>COMPLETED</td><td>1458</td><td>12.218219</td></tr><tr><td>f</td><td>null</td><td>9148</td><td>76.66136</td></tr></tbody></table></div>

# %%
appointment_status_requested = appointment_status.filter(col('appointment_requested')== 't').sort('%')
display(appointment_status_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>CREATED</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>SCHEDULED</td><td>9</td><td>0.0754211</td></tr><tr><td>t</td><td>REQUESTED</td><td>46</td><td>0.38548562</td></tr><tr><td>t</td><td>CANCELLED</td><td>1271</td><td>10.651135</td></tr><tr><td>t</td><td>COMPLETED</td><td>1458</td><td>12.218219</td></tr></tbody></table></div>

# %%
appointment_status_not_requested = appointment_status.filter(col('appointment_requested')== 'f').sort('%')
display(appointment_status_not_requested)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>f</td><td>null</td><td>9148</td><td>76.66136</td></tr></tbody></table></div>

# %% [markdown]
# ## Exploration on target variables [requested and billed]

# %%
t_t = nested_groupby_percentage.filter((col('appointment_requested') == 't') & (col('appointment_billed') == 't'))
display(t_t)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>REQUESTED</td><td>t</td><td>34</td><td>0.28492415</td></tr><tr><td>t</td><td>SCHEDULED</td><td>t</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>COMPLETED</td><td>t</td><td>1163</td><td>9.746082</td></tr><tr><td>t</td><td>CREATED</td><td>t</td><td>1</td><td>0.0083801225</td></tr></tbody></table></div>

# %%
t_f = nested_groupby_percentage.filter((col('appointment_requested') == 't') & (col('appointment_billed') == 'f'))
display(t_f)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>SCHEDULED</td><td>f</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>COMPLETED</td><td>f</td><td>295</td><td>2.472136</td></tr><tr><td>t</td><td>CANCELLED</td><td>f</td><td>1270</td><td>10.6427555</td></tr><tr><td>t</td><td>REQUESTED</td><td>f</td><td>8</td><td>0.06704098</td></tr></tbody></table></div>

# %%
f_t = nested_groupby_percentage.filter((col('appointment_requested') == 'f') & (col('appointment_billed') == 't'))
display(f_t)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody></tbody></table></div>

# %%
f_f = nested_groupby_percentage.filter((col('appointment_requested') == 'f') & (col('appointment_billed') == 'f'))
display(f_f)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody></tbody></table></div>

# %%
null_billed = nested_groupby_percentage.filter(
  ((col('appointment_requested') == 't') |  (col('appointment_requested') == 'f')) &
  (col('appointment_billed').isNull())
)
display(null_billed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>CANCELLED</td><td>null</td><td>1</td><td>0.0083801225</td></tr><tr><td>f</td><td>null</td><td>null</td><td>9148</td><td>76.66136</td></tr><tr><td>t</td><td>REQUESTED</td><td>null</td><td>4</td><td>0.03352049</td></tr></tbody></table></div>

# %%
not_null_billed = nested_groupby_percentage.filter(
  ((col('appointment_requested') == 't') |  (col('appointment_requested') == 'f')) &
  (col('appointment_billed').isNotNull())
)
display(not_null_billed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_requested</th><th>appointment_status</th><th>appointment_billed</th><th>count</th><th>%</th></tr></thead><tbody><tr><td>t</td><td>SCHEDULED</td><td>f</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>REQUESTED</td><td>t</td><td>34</td><td>0.28492415</td></tr><tr><td>t</td><td>SCHEDULED</td><td>t</td><td>8</td><td>0.06704098</td></tr><tr><td>t</td><td>COMPLETED</td><td>t</td><td>1163</td><td>9.746082</td></tr><tr><td>t</td><td>COMPLETED</td><td>f</td><td>295</td><td>2.472136</td></tr><tr><td>t</td><td>CANCELLED</td><td>f</td><td>1270</td><td>10.6427555</td></tr><tr><td>t</td><td>CREATED</td><td>t</td><td>1</td><td>0.0083801225</td></tr><tr><td>t</td><td>REQUESTED</td><td>f</td><td>8</td><td>0.06704098</td></tr></tbody></table></div>

# %%
print(df.count())
df_no_null = df.dropna()
print(df_no_null.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">11933
# 2772
# </div>

# %%
facebook_source = df.select('source').filter(col('source').like('%facebook%')).groupby('source').count()
display(facebook_source)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source</th><th>count</th></tr></thead><tbody><tr><td>lm.facebook.com</td><td>60</td></tr><tr><td>l.facebook.com</td><td>35</td></tr><tr><td>l.facebook.com:80</td><td>1</td></tr><tr><td>www.facebook.com</td><td>104</td></tr><tr><td>l.facebook.com:443</td><td>1</td></tr><tr><td>m.facebook.com</td><td>90</td></tr><tr><td>facebook</td><td>7350</td></tr></tbody></table></div>

# %%
opencare_source = df.select('source').filter(col('source').like('%opencare%')).groupby('source').count()
display(opencare_source)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source</th><th>count</th></tr></thead><tbody><tr><td>try.opencare.com</td><td>407</td></tr><tr><td>patient.opencare.com</td><td>3</td></tr><tr><td>try.opencare.com:80</td><td>1</td></tr><tr><td>www.opencare.com</td><td>633</td></tr><tr><td>opencare.com</td><td>1</td></tr><tr><td>app.opencare.com</td><td>4</td></tr><tr><td>www.opencare.com:443</td><td>10</td></tr></tbody></table></div>

# %%
df.groupBy('appointment_requested').count().withColumn('%' , percentage('count')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------+-----+--------+
# appointment_requested|count|       %|
# +---------------------+-----+--------+
#                     f| 9148|76.66136|
#                     t| 2785|23.33864|
# +---------------------+-----+--------+
#
# </div>
