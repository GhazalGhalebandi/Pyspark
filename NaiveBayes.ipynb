# %%
# %run "./data-pipeline-naive-bayes2"

# %%
# Add libraries needed for the ML pipeline
from pyspark.ml import Pipeline
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import *
from pyspark.ml.tuning import *
from pyspark.ml.evaluation import *
from pyspark.ml.classification import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Optional: Printing training_data and testing_data count
print(training_dataset.count())
print(testing_dataset.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">221225
# 1266468
# </div>

# %%
assembler = VectorAssembler(
    inputCols=["p_positive_industry", "p_positive_pitch" , "p_positive_salary"],
    outputCol="features")
train = assembler.transform(training_dataset)

assembler = VectorAssembler(
    inputCols=["p_positive_industry", "p_positive_pitch" , "p_positive_salary"],
    outputCol="features")
test = assembler.transform(testing_dataset)

display(
  train.select('application_id', 'job_industry_code', 'cand_industry_code', 'label', 'p_positive_industry','p_positive_pitch', 'p_positive_salary', 'features')
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>application_id</th><th>job_industry_code</th><th>cand_industry_code</th><th>label</th><th>p_positive_industry</th><th>p_positive_pitch</th><th>p_positive_salary</th><th>features</th></tr></thead><tbody><tr><td>389560396</td><td>36</td><td>11</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>388833851</td><td>10</td><td>51</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>388553176</td><td>10</td><td>0</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>390344332</td><td>51</td><td>35</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>391169388</td><td>51</td><td>27</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>389517490</td><td>51</td><td>58</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>389014055</td><td>22</td><td>7</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>389555649</td><td>42</td><td>42</td><td>0.0</td><td>0.0626356741498</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.0626356741498, 0.316407750511, 0.496363430896))</td></tr><tr><td>392096843</td><td>42</td><td>18</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>391293271</td><td>42</td><td>1</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>389435104</td><td>42</td><td>2</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>389659639</td><td>11</td><td>13</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>389616014</td><td>11</td><td>11</td><td>0.0</td><td>0.0626356741498</td><td>0.316407750511</td><td>0.00232342637586</td><td>List(1, 3, List(), List(0.0626356741498, 0.316407750511, 0.00232342637586))</td></tr><tr><td>390454379</td><td>11</td><td>1</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>390350544</td><td>11</td><td>11</td><td>0.0</td><td>0.0626356741498</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.0626356741498, 0.183328717807, 0.496363430896))</td></tr><tr><td>389673682</td><td>11</td><td>35</td><td>0.0</td><td>0.437100794168</td><td>0.183328717807</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td></tr><tr><td>392128032</td><td>11</td><td>27</td><td>0.0</td><td>0.437100794168</td><td>0.316407750511</td><td>0.496363430896</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td></tr><tr><td>389660979</td><td>11</td><td>64</td><td>0.0</td><td>0.437100794168</td><td>0.31 ...

# %%
nb = NaiveBayes(smoothing=1.0, modelType="multinomial")
model = nb.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = model.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluator = MulticlassClassificationEvaluator()
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">30</span><span class="ansired">]: </span>0.5854361934844646
# </div>

# %%
evaluator = BinaryClassificationEvaluator()
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">31</span><span class="ansired">]: </span>0.7081385416799483
# </div>

# %%
predictions.groupBy('prediction').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------+
# prediction| count|
# +----------+------+
#        0.0|598377|
#        1.0|668091|
# +----------+------+
#
# </div>

# %%
display(
  predictions.select('label','prediction').groupBy('label','prediction').agg(count('*').alias('total'))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th><th>total</th></tr></thead><tbody><tr><td>1.0</td><td>1.0</td><td>61758</td></tr><tr><td>0.0</td><td>1.0</td><td>606333</td></tr><tr><td>1.0</td><td>0.0</td><td>49044</td></tr><tr><td>0.0</td><td>0.0</td><td>549333</td></tr></tbody></table></div>

# %%
df = predictions.select('label','prediction').groupBy('label','prediction').agg(count('*').alias('total'))
v1 = df.collect()[0][2]
v2 = df.collect()[1][2]
v3 = df.collect()[2][2]
v4 = df.collect()[3][2]
total_count = predictions.count()

# true positives
TP_11 = (float(v1) / float(total_count))*100
print('TP_11: ' + str(TP_11))+ '\n'

# true negatives
TN_00 = (float(v4) / float(total_count))*100
print('TN_00: ' + str(TN_00))+ '\n' + '\n'
  
# False Positive 
FP_01 = (float(v2) / float(total_count))*100
print('FP_01: ' + str(FP_01)) + '\n' 

# false negative
FN_10 = (float(v3) / float(total_count))*100
print('FN_10: ' + str(FN_10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">TP_11: 4.87639640323
#
# TN_00: 43.3751977942
#
#
# FP_01: 47.8759036944
#
# FN_10: 3.87250210823
# </div>

# %%
predictions_logloss = predictions.select('application_id', 'label', 'features', 'prediction', 'probability').withColumn(
  'positive_probability', positive_probability(predictions.probability)
).withColumn(
  'negative_probability', negative_probability(predictions.probability)
)
predictions_logloss = predictions_logloss.withColumn(
  'score', score(predictions_logloss.positive_probability, predictions_logloss.negative_probability)
)
predictions_logloss = predictions_logloss.withColumn(
  'logloss', binary_logloss(predictions_logloss.label, predictions_logloss.score)
)

predictions_logloss.agg(avg('logloss')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#       avg(logloss)|
# +------------------+
# 0.6940813624440146|
# +------------------+
#
# </div>

# %%
predictions_logloss.agg(avg('score')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#         avg(score)|
# +------------------+
# 0.5007961040405768|
# +------------------+
#
# </div>

# %%
display(predictions_logloss)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>application_id</th><th>label</th><th>features</th><th>prediction</th><th>probability</th><th>positive_probability</th><th>negative_probability</th><th>score</th><th>logloss</th></tr></thead><tbody><tr><td>399883966</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td><td>1.0</td><td>List(1, 2, List(), List(0.499760861055633, 0.500239138944367))</td><td>0.500239138944367</td><td>0.499760861055633</td><td>0.500239138944367</td><td>0.6936255728600305</td></tr><tr><td>393171301</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>397455095</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>399252377</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>398321736</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td><td>1.0</td><td>List(1, 2, List(), List(0.499760861055633, 0.500239138944367))</td><td>0.500239138944367</td><td>0.499760861055633</td><td>0.500239138944367</td><td>0.6936255728600305</td></tr><tr><td>393832482</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>398341887</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td><td>1.0</td><td>List(1, 2, List(), List(0.499760861055633, 0.500239138944367))</td><td>0.500239138944367</td><td>0.499760861055633</td><td>0.500239138944367</td><td>0.6936255728600305</td></tr><tr><td>396897212</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td><td>1.0</td><td>List(1, 2, List(), List(0.499760861055633, 0.500239138944367))</td><td>0.500239138944367</td><td>0.499760861055633</td><td>0.500239138944367</td><td>0.6936255728600305</td></tr><tr><td>393696224</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>391130649</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.316407750511, 0.496363430896))</td><td>1.0</td><td>List(1, 2, List(), List(0.499760861055633, 0.500239138944367))</td><td>0.500239138944367</td><td>0.499760861055633</td><td>0.500239138944367</td><td>0.6936255728600305</td></tr><tr><td>392701738</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.4990405568611047</td><td>0.6912301329926198</td></tr><tr><td>391735323</td><td>0.0</td><td>List(1, 3, List(), List(0.437100794168, 0.183328717807, 0.496363430896))</td><td>0.0</td><td>List(1, 2, List(), List(0.5009594431388954, 0.4990405568611047))</td><td>0.4990405568611047</td><td>0.5009594431388954</td><td>0.499040 ...
